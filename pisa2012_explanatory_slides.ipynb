# %% [markdown]
# # How Student Background Ties into Student Drive and Scores
# ## by Marc Angelo Acebedo

# %% [markdown]
# ## Investigation Overview
#
# > For the PISA 2012 dataset, I wanted to see how environment and background factors into students' drive and academic performance.
#
# ## Dataset Overview
#
# > The data consists of around 460,000 students from 65 countries. I isolate my focus on the above listed 4 attributes, and the resulting dataset went down from over 600 columns to only 14. Many columns were dropped due to irrelevance in my investigation purposes. Here is a breakdown of each variable group:

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from IPython.display import Image

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df = pd.read_csv('./data/pisa2012_clean.csv')

# %% [markdown]
# ### CAUSES
# - **Environment**: Teacher helpfulness, sense of belonging, acculturation
# - **Background**: Country, gender, parent occupational background, mother immigrant background

# %% [markdown]
# ### EFFECTS
# - **Student Drive**: Work ethic, future optimism, self esteem
# - **Academic Performance**: Math, Reading, and Science Scores

# %% [markdown]
# > Though my focus could have taken many different paths, I chose the following two approaches for my key insights.

# %% [markdown]
# # Approach 1. Immigrant Background by Drive and Academic Performance

# %% [markdown]
# ## Distribution of Students with Immigrant Mothers
#
# Of all the students who answered the Mother Immigrant question, the overwhelming majority of students answered "yes" at 77.83%. The difference is so staggering that the difference in proportions is 55.66% in favor of students with immigrant backgrounds.

# %%
Image(filename = './visuals/univariate/mother-immigrant.png')

# %% [markdown]
# ## Mother Immigrant Background by Student Drive Factors
#
# Students who do not come from an immigrant background tend to score higher on all environment variables than those who do.
#
# This is intuitive enough, as I would assume non-immigrants are much more familiar with their country of citizenship, and thus would adapt better.

# %%
Image(filename = './visuals/bivariate/drive-m-immigrant.png')

# %% [markdown]
# **Observation 1:** Students who do not come from an immigrant background tend to score higher on all environment variables than those who do. This is intuitive enough, as I would assume non-immigrants are much more familiar with their country of citizenship, and thus would adapt better.
#
# **Observation 2:** Again, future optimism scores higher on average for all environment variables in comparison to work ethic and self esteem.

# %% [markdown]
# ## Immigrant Background by Academic Performance (Scores)
#
# *There is a vast disparity in records for students whose mothers aren't or are immigrants. Therefore, we cannot rely on the following histograms for sole counts.*
#
# As it was previously established, students from immigrant backgrounds score lower for work ethic, future optimism, and self-esteem. However, ***they score consistently higher than students not from an immigrant background.***
#
# This is a key takeaway: ***students with immigrant mothers tend to have a lower student drive and a more pessimistic views of themselves, but consistently outperform non-immigrant students by a large margin.***

# %%
Image(filename = './visuals/bivariate/immigrant-math.png')

# %%
Image(filename = './visuals/bivariate/immigrant-reading.png')

# %%
Image(filename = './visuals/bivariate/immigrant-science.png')

# %% [markdown]
# # Approach 2. Gender by Student Drive and Academic Performance

# %% [markdown]
# ## Distribution of Male and Female Students
#
# Gender is about **evenly split** with female students at 50.5% and males at 49.5%, so we can safely say that conclusions drawn by gender are fair and representative.

# %%
Image(filename = './visuals/univariate/gender-count.png')

# %% [markdown]
# ## Gender by Student Drive Features
#
# Girls tend to have a ***higher work ethic but significantly less self-esteem*** than boys. Meanwhile, there is no gender gap for future optimism.
#
# This is a key takeaway as this discovery reflects the reality that girls are often discouraged and intimidated in academic settings, despite putting more in more effort on average.

# %%
Image(filename = './visuals/bivariate/drive-gender.png')

# %% [markdown]
# ## Gender by Academic Performance (Scores)
#
# The count by gender is evenly split, so we can draw reliable conclusions from the following histograms.

# %%
Image(filename = './visuals/bivariate/math-score-gender.png')

# %%
Image(filename = './visuals/bivariate/reading-score-gender.png')

# %%
Image(filename = './visuals/bivariate/science-score-gender.png')

# %% [markdown]
# ***The patterns in the histograms correlating score and gender show more girls scoring the average score per subject than boys.***
#
# **Observation 1:** The only truly notable difference in the gender gap is under ***reading score, where girls outperform boys on average***, as indicated by the box plots.
#
# **Observation 2:** Under math and science scores, more girls than boys scored around 500.
#
# **Observation 3:** Under reading scores, more boys than girls score between 0 - 500, but more girls than boys score between 500 - 800.

# %% [markdown]
# ### Is this outperformance in reading scores due to girls' higher work ethic? What about the other scores? Let's look deeper.

# %% [markdown]
# ## Gender by Academic Performance and Work Ethic
#
# ### Despite girls having an overall higher work ethic, if a boy and girl had the same work ethic score, *the boy is most certainly guaranteed to score higher for math.* However, the *contrary is true for reading scores.*

# %%
Image('./visuals/multivariate/work-ethic-math-gender.png')

# %%
Image('./visuals/multivariate/work-ethic-reading-gender.png')

# %%
Image('./visuals/multivariate/work-ethic-science-gender.png')

# %% [markdown]
# **Observation 1:** The higher the student's work ethic, boys *always* outperform girls for mean math scores.
#
# **Observation 2:** The higher the student's work ethic, girls *always* outperform boys for mean reading scores.
#
# **Observation 3:** There are many overlaps between science scores between boys and girls, so it is hard to draw a trend conclusion. We can only say that the mean science score vs. work ethic depicts an overall positive trend for both genders.

# %% [markdown]
# > Once you're ready to finish your presentation, check your output by using
# nbconvert to export the notebook and set up a server for the slides. From the
# terminal or command line, use the following expression:
# > > `jupyter nbconvert <file_name>.ipynb --to slides --post serve --template output_toggle`
#
# > This should open a tab in your web browser where you can scroll through your
# presentation. Sub-slides can be accessed by pressing 'down' when viewing its parent
# slide. Make sure you remove all of the quote-formatted guide notes like this one
# before you finish your presentation!
